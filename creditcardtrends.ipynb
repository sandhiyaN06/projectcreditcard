# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#Reading the CSV file
data=pd.read_csv("/content/credit_card_trend.csv")

# %%
#Reading and viewing the dataset
data.head(5)
# Out:
#    Customer_ID  Age  Gender Income_Level Education_Level Marital_Status  \
# 0  CUST0000001   56  Female       Medium        Master's        Married
# 1  CUST0000002   69  Female         High        Master's       Divorced
# 2  CUST0000003   46    Male         High        Master's       Divorced
# 3  CUST0000004   32    Male          Low      Bachelor's         Single
# 4  CUST0000005   60  Female       Medium     High School        Married
#
#    Credit_Score  Monthly_Expenditure Payment_Default Card_Type  \
# 0           405               621.30              No      Gold
# 1           763              2526.34              No  Standard
# 2           545              3085.19             Yes      Gold
# 3           380              1447.05              No      Gold
# 4           695              3612.31              No      Gold
#
#    Transaction_Frequency  Online_Purchase_Ratio Spending_Category  \
# 0                     22                   0.64        Healthcare
# ...

# %%
#Displaying columns
data.columns
# Out:
# Index(['Customer_ID', 'Age', 'Gender', 'Income_Level', 'Education_Level',
#        'Marital_Status', 'Credit_Score', 'Monthly_Expenditure',
#        'Payment_Default', 'Card_Type', 'Transaction_Frequency',
#        'Online_Purchase_Ratio', 'Spending_Category', 'Transaction_Amount',
#        'Monthly_Income', 'Monthly_Income_INR', 'Monthly_Expenditure_INR',
#        'Transaction_Amount_INR', 'City_or_State'],
#       dtype='object')

# %%
#Finding null values
data.isnull().sum()
# Out:
# Customer_ID                0
# Age                        0
# Gender                     0
# Income_Level               0
# Education_Level            0
# Marital_Status             0
# Credit_Score               0
# Monthly_Expenditure        0
# Payment_Default            0
# Card_Type                  0
# Transaction_Frequency      0
# Online_Purchase_Ratio      0
# Spending_Category          0
# Transaction_Amount         0
# Monthly_Income             0
# Monthly_Income_INR         0
# Monthly_Expenditure_INR    0
# Transaction_Amount_INR     0
# City_or_State              0
# dtype: int64

# %%
#Finding duplicate values
data.duplicated().sum()
# Out:
# 0

# %%
#Deriving statistical information
data.describe()
# Out:
#                Age  Credit_Score  Monthly_Expenditure  Transaction_Frequency  \
# count  2000.000000   2000.000000          2000.000000            2000.000000
# mean     49.114000    573.374000          2562.864700              26.860500
# std      17.926564    160.770173          1425.608148              12.901173
# min      18.000000    300.000000           100.770000               5.000000
# 25%      34.000000    433.000000          1335.640000              16.000000
# 50%      49.000000    575.000000          2522.975000              27.000000
# 75%      65.000000    713.000000          3829.732500              38.000000
# max      79.000000    850.000000          4998.400000              49.000000
#
#        Online_Purchase_Ratio  Transaction_Amount  Monthly_Income  \
# count            2000.000000         2000.000000     2000.000000
# mean                0.509245          135.758365     5300.721165
# std                 0.231092          140.242766     3382.502020
# ...

# %%
#Deriving statistical information of object columns
data.describe(include='object')
# Out:
#         Customer_ID  Gender Income_Level Education_Level Marital_Status  \
# count          2000    2000         2000            2000           2000
# unique         2000       3            3               4              3
# top     CUST0000001  Female       Medium      Bachelor's        Married
# freq              1     965         1027             910           1021
#
#        Payment_Default Card_Type Spending_Category  City_or_State
# count             2000      2000              2000           2000
# unique               2         3                10             20
# top                 No  Standard            Travel  Uttar Pradesh
# freq              1783       979               228            120

# %%
#Merge function
data1=data[['Customer_ID','Age','Credit_Score']]
data2=data[['Customer_ID','Monthly_Income','Transaction_Amount']]
result=pd.merge(data1,data2,on='Customer_ID')
result
# Out:
#       Customer_ID  Age  Credit_Score  Monthly_Income  Transaction_Amount
# 0     CUST0000001   56           405         5627.16               28.24
# 1     CUST0000002   69           763        14438.15               58.75
# 2     CUST0000003   46           545        10728.22              342.80
# 3     CUST0000004   32           380         2849.00               72.35
# 4     CUST0000005   60           695         4376.56              240.82
# ...           ...  ...           ...             ...                 ...
# 1995  CUST0001996   52           580         6904.50              134.49
# 1996  CUST0001997   61           810        12660.50              103.77
# 1997  CUST0001998   77           765         4615.26               17.66
# 1998  CUST0001999   62           414         2795.99              106.57
# 1999  CUST0002000   51           535         2267.03              106.21
#
# [2000 rows x 5 columns]

# %%
#Pivot tables to find the credit card usage based on age
table1=pd.pivot_table(data,values='Transaction_Amount',index='Age',aggfunc=np.sum)
table1
# Out:
# <ipython-input-33-6ac006a854fc>:1: FutureWarning: The provided callable <function sum at 0x7ba6663ad080> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   table1=pd.pivot_table(data,values='Transaction_Amount',index='Age',aggfunc=np.sum)
#      Transaction_Amount
# Age
# 18              4050.97
# 19              3393.45
# 20              3955.31
# 21              3424.70
# 22              4109.53
# ..                  ...
# 75              4492.56
# 76              3876.51
# 77              4785.20
# 78              3547.53
# 79              5636.69
#
# [62 rows x 1 columns]

# %%
#Visualizing the data using plots
age=data['Age']
transamt=data['Transaction_Amount']

plt.scatter(age,transamt,color='m')
plt.xlabel('Age')
plt.ylabel('Transaction_Amount')
plt.title('Transactions based on Age')
plt.show()

# %%
#Pivot tables to find the credit card usage based on Gender
table2=pd.pivot_table(data,values='Transaction_Amount',index='Gender',aggfunc=np.sum)
table2
# Out:
# <ipython-input-10-958f1f2134eb>:1: FutureWarning: The provided callable <function sum at 0x7ba6663ad080> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   table2=pd.pivot_table(data,values='Transaction_Amount',index='Gender',aggfunc=np.sum)
#         Transaction_Amount
# Gender
# Female           129551.52
# Male             130714.63
# Other             11250.58

# %%
#Visualizing the data using plots
gender=data['Gender']
transamt=data['Transaction_Amount']

plt.bar(gender,transamt,color='c')
plt.xlabel('Gender')
plt.ylabel('Transaction_Amount')
plt.title('Credit card Usage Patterns based on Gender')
plt.show()

# %%
#Pivot tables to find the credit card usage based on Monthly Income
table3=pd.pivot_table(data,values='Transaction_Amount',index='Monthly_Income',aggfunc=np.sum)
table3
# Out:
# <ipython-input-12-c4d8d7701493>:1: FutureWarning: The provided callable <function sum at 0x7ba6663ad080> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   table3=pd.pivot_table(data,values='Transaction_Amount',index='Monthly_Income',aggfunc=np.sum)
#                 Transaction_Amount
# Monthly_Income
# 1003.83                     214.85
# 1003.87                     629.93
# 1006.56                       6.74
# 1008.17                      86.63
# 1021.79                      74.32
# ...                            ...
# 14895.40                     52.64
# 14904.57                     54.19
# 14926.06                    156.62
# 14947.05                    269.65
# 14979.51                    211.05
#
# [1997 rows x 1 columns]

# %%
#Visualizing the data using plots
x=data['Monthly_Income']
y=data['Transaction_Amount']

plt.bar(x,y,color='r')
plt.xlabel('Monthly_Income (in $)')
plt.ylabel('Transaction_Amount (in $)')
plt.title('Credit card usage based on Monthly Income')
plt.show()

# %%
#Pivot tables to find the credit card usage based on Marital Status
table4=pd.pivot_table(data,values='Transaction_Amount',index='Marital_Status',aggfunc=np.sum)
table4
# Out:
# <ipython-input-14-3e6a8bfcfaed>:1: FutureWarning: The provided callable <function sum at 0x7ba6663ad080> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   table4=pd.pivot_table(data,values='Transaction_Amount',index='Marital_Status',aggfunc=np.sum)
#                 Transaction_Amount
# Marital_Status
# Divorced                  28532.52
# Married                  136504.27
# Single                   106479.94

# %%
#Visualizing the data using plots
x=data['Marital_Status']
y=data['Transaction_Amount']

plt.bar(x,y,color='#C8A2C8')
plt.xlabel('Marital_Status')
plt.ylabel('Transaction_Amount')
plt.title('Credit card usage based on MaritalStatus')
plt.show()

# %%
#Pivot tables to find the credit card usage based on income level
table5=pd.pivot_table(data,values='Transaction_Amount',index='Income_Level',aggfunc=np.sum)
table5
# Out:
# <ipython-input-16-7637a92255e5>:1: FutureWarning: The provided callable <function sum at 0x7ba6663ad080> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   table5=pd.pivot_table(data,values='Transaction_Amount',index='Income_Level',aggfunc=np.sum)
#               Transaction_Amount
# Income_Level
# High                    49897.26
# Low                     79928.92
# Medium                 141690.55

# %%
#Visualizing the data using pie chart
x = data['Income_Level']
counts = x.value_counts()  # Get unique categories and their counts

plt.pie(counts, labels=counts.index, autopct='%1.2f%%')  # Use unique labels
plt.legend(title=" Income Levels of customers", loc="lower right")
plt.show()

# %%
#Pivot tables to find the credit card usage on differrnt categories of expenses
table6=pd.pivot_table(data,values='Transaction_Amount',index='Spending_Category',aggfunc=np.sum)
table6
# Out:
# <ipython-input-18-072b8b8f45e7>:1: FutureWarning: The provided callable <function sum at 0x7ba6663ad080> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   table6=pd.pivot_table(data,values='Transaction_Amount',index='Spending_Category',aggfunc=np.sum)
#                    Transaction_Amount
# Spending_Category
# Dining                       23880.91
# Education                    27287.02
# Electronics                  29489.21
# Entertainment                25083.00
# Groceries                    25068.65
# Healthcare                   34563.90
# Online Shopping              27342.55
# Other                        26117.68
# Travel                       29948.08
# Utilities                    22735.73

# %%
#Visualizing the data using plots
x=data['Spending_Category']
y=data['Transaction_Amount']

plt.bar(x,y,color='#AC9362')
plt.xticks(rotation=90)
plt.xlabel('Spending_Category')
plt.ylabel('Transaction_Amount')
plt.title('Spendings on different categories')
plt.show()

# %%
#Pivot tables to find the credit card usage in different geographical locations
table7=pd.pivot_table(data,values='Transaction_Amount',index='City_or_State',aggfunc=np.sum)
table7
# Out:
# <ipython-input-20-9fcffc024000>:1: FutureWarning: The provided callable <function sum at 0x7ba6663ad080> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   table7=pd.pivot_table(data,values='Transaction_Amount',index='City_or_State',aggfunc=np.sum)
#                 Transaction_Amount
# City_or_State
# Ahmedabad                 11425.53
# Bangalore                  9745.71
# Chennai                   11959.09
# Delhi                     12268.71
# Gujarat                   12585.10
# Hyderabad                 13372.81
# Jaipur                    15090.74
# Karnataka                 14957.82
# Kolkata                   12646.62
# Lucknow                   14319.10
# Madhya Pradesh            10458.09
# Maharashtra               17872.92
# Mumbai                    11214.82
# Pune                      14724.57
# Punjab                    18764.30
# ...

# %%
#Visualizing the data using plots
x=data['City_or_State']
y=data['Transaction_Amount']

plt.bar(x,y,color='#87CEEB')
plt.xticks(rotation=90)
plt.xlabel('City_or_State')
plt.ylabel('Transaction_Amount')
plt.title('Spending Patterns in different locations')
plt.show()

# %%
#Pivot tables to find the monthly income and monthly expenditure
table8=pd.pivot_table(data,values='Monthly_Expenditure',index='Monthly_Income',aggfunc=np.sum)
table8
# Out:
# <ipython-input-22-5ea0a2043e8f>:1: FutureWarning: The provided callable <function sum at 0x7ba6663ad080> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   table8=pd.pivot_table(data,values='Monthly_Expenditure',index='Monthly_Income',aggfunc=np.sum)
#                 Monthly_Expenditure
# Monthly_Income
# 1003.83                     3437.57
# 1003.87                     3779.55
# 1006.56                      202.14
# 1008.17                     3638.56
# 1021.79                     1857.93
# ...                             ...
# 14895.40                     684.33
# 14904.57                    1896.67
# 14926.06                    4385.42
# 14947.05                    2966.19
# 14979.51                    3165.77
#
# [1997 rows x 1 columns]

# %%
#Visualizing the data using plots
x=data['Monthly_Income']
y=data['Monthly_Expenditure']

plt.bar(x,y,color='g')
plt.xlabel('Monthly_Income')
plt.ylabel('Monthly_Expenditure')
plt.title('Monthly_Expenditure based on Monthly_Income')
plt.show()

# %%
#Pie chart to depict different types of card holders
x=data['Card_Type']

counts = x.value_counts()  # Get unique categories and their counts

plt.pie(counts, labels=counts.index, autopct='%1.2f%%')  # Use unique labels
plt.legend(title="Card Types of Customers", loc="lower right")
plt.show()

# %%
#Visualizing the data using plots
x=data['Transaction_Amount']
y=data['Card_Type']

plt.bar(y,x,color='y')
plt.ylabel('Transaction_Amount')
plt.xlabel('Card_Type')
plt.title('Transactions based on CardType of customers')
plt.show()

# %%
#Categorizing Spending Patterns by Age
datas = {
    'Age': data['Age'],
    'Spending Category': data['Spending_Category'],
    'Amount': data['Transaction_Amount']
}

# Convert to DataFrame
df = pd.DataFrame(datas)

# Define Age Groups
age_bins = [18, 25, 35, 45, 60, 100]  # Define age range bins
age_labels = ['18-25', '26-35', '36-45', '46-60', '60+']  # Age group labels

# Categorize ages into age groups
df['Age Group'] = pd.cut(df['Age'], bins=age_bins, labels=age_labels, right=False)

# Group data by Age Group and Spending Category
grouped_data = df.groupby(['Age Group', 'Spending Category'])['Amount'].sum().reset_index()

# Pivot table for visualization
pivot_data = grouped_data.pivot(index='Spending Category', columns='Age Group', values='Amount')

# Display grouped spending patterns
print(grouped_data)

# Bar Plot to visualize spending trends
plt.figure(figsize=(12, 6))
sns.barplot(x='Age Group', y='Amount', hue='Spending Category', data=grouped_data)
plt.title("Spending Categories by Age Group")
plt.xlabel("Age Group")
plt.ylabel("Total Spending")
plt.legend(title="Spending Category")
plt.show()
# Out:
# <ipython-input-60-4751287dd669>:18: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = df.groupby(['Age Group', 'Spending Category'])['Amount'].sum().reset_index()
#    Age Group Spending Category    Amount
# 0      18-25            Dining   3063.43
# 1      18-25         Education   2805.94
# 2      18-25       Electronics   1646.10
# 3      18-25     Entertainment   1604.00
# 4      18-25         Groceries   3250.36
# 5      18-25        Healthcare   4469.92
# 6      18-25   Online Shopping   2978.02
# 7      18-25             Other   2273.42
# 8      18-25            Travel   2217.02
# 9      18-25         Utilities   1898.10
# 10     26-35            Dining   4255.25
# 11     26-35         Education   4660.96
# 12     26-35       Electronics   1930.33
# ...

# %%
#Categorizing Spending Patterns by Marital Status
datas2 = {
    'Marital_Status': data['Marital_Status'],
    'Spending Category': data['Spending_Category'],
    'Amount': data['Transaction_Amount']
}

# Convert to DataFrame
df = pd.DataFrame(datas)

# Group data by Age Group and Spending Category
grouped_data2 = df.groupby(['Marital_Status', 'Spending Category'])['Amount'].sum().reset_index()

# Pivot table for visualization
pivot_data2 = grouped_data2.pivot(index='Spending Category', columns='Marital_Status', values='Amount')

# Display grouped spending patterns
print(grouped_data2)

# Bar Plot to visualize spending trends
plt.figure(figsize=(12, 6))
sns.barplot(x='Marital_Status', y='Amount', hue='Spending Category', data=grouped_data)
plt.title("Spending Categories by Marital Status")
plt.xlabel("Marital Status ")
plt.ylabel("Total Spending")
plt.legend(title="Spending Category")
plt.show()
# Out:
#    Marital_Status Spending Category    Amount
# 0        Divorced            Dining   2271.86
# 1        Divorced         Education   3127.83
# 2        Divorced       Electronics   3331.58
# 3        Divorced     Entertainment   2309.09
# 4        Divorced         Groceries   4426.90
# 5        Divorced        Healthcare   1909.33
# 6        Divorced   Online Shopping   3580.17
# 7        Divorced             Other   2933.72
# 8        Divorced            Travel   2809.28
# 9        Divorced         Utilities   1832.76
# 10        Married            Dining  11857.09
# 11        Married         Education  14460.94
# 12        Married       Electronics  14267.59
# 13        Married     Entertainment  13111.76
# 14        Married         Groceries   9089.39
# 15        Married        Healthcare  19172.53
# 16        Married   Online Shopping  13362.01
# 17        Married             Other  13670.70
# 18        Married            Travel  15333.02
# ...

# %%
#Spendings of card holders by Income Level
datas3 = {
    'Income': data['Income_Level'],
    'Type': data['Card_Type'],
    'Amount': data['Transaction_Amount']
}

# Convert to DataFrame
df = pd.DataFrame(datas3)

# Group data by Age Group and Spending Category
grouped_data3 = df.groupby(['Income', 'Type'])['Amount'].sum().reset_index()

# Pivot table for visualization
pivot_data3 = grouped_data3.pivot(index='Type', columns='Income', values='Amount')

# Display grouped spending patterns
print(grouped_data3)

# Bar Plot to visualize spending trends

plt.figure(figsize=(12, 6))
plt.figure(figsize=(12, 6))
sns.barplot(x='Income', y='Amount', hue='Type', data=grouped_data3)
plt.title("Spendings of card holders by Income Level")
plt.xlabel("Income level")
plt.ylabel("Amount")
plt.legend(title="Type of Card")
plt.show()
# Out:
#    Income      Type    Amount
# 0    High      Gold  14865.73
# 1    High  Platinum  10907.68
# 2    High  Standard  24123.85
# 3     Low      Gold  23658.93
# 4     Low  Platinum  14363.81
# 5     Low  Standard  41906.18
# 6  Medium      Gold  46285.41
# 7  Medium  Platinum  26961.76
# 8  Medium  Standard  68443.38

# %%
#Categorizing Spending Patterns by Income Level
datas4 = {
    'Income': data['Income_Level'],
    'Spending Category': data['Spending_Category'],
    'Amount': data['Transaction_Amount']
}

# Convert to DataFrame
df = pd.DataFrame(datas4)

# Group data by Age Group and Spending Category
grouped_data4 = df.groupby(['Income', 'Spending Category'])['Amount'].sum().reset_index()

# Pivot table for visualization
pivot_data4 = grouped_data4.pivot(index='Spending Category', columns='Income', values='Amount')

# Display grouped spending patterns
print(grouped_data4)

# Bar Plot to visualize spending trends
plt.figure(figsize=(12, 6))
sns.barplot(x='Income', y='Amount', hue='Spending Category', data=grouped_data4)
plt.title("Spending Categories by Income Level")
plt.xlabel("Income Level")
plt.ylabel("Total Spending")
plt.legend(title="Spending Category")
plt.show()
# Out:
#     Income Spending Category    Amount
# 0     High            Dining   4629.81
# 1     High         Education   4492.19
# 2     High       Electronics   5291.80
# 3     High     Entertainment   3356.55
# 4     High         Groceries   6642.83
# 5     High        Healthcare   5155.28
# 6     High   Online Shopping   4365.98
# 7     High             Other   4877.43
# 8     High            Travel   5927.60
# 9     High         Utilities   5157.79
# 10     Low            Dining   7676.34
# 11     Low         Education   8486.43
# 12     Low       Electronics   8515.17
# 13     Low     Entertainment   7931.13
# 14     Low         Groceries   6889.42
# 15     Low        Healthcare  11542.59
# 16     Low   Online Shopping   5587.42
# 17     Low             Other   7296.52
# 18     Low            Travel   9128.79
# 19     Low         Utilities   6875.11
# 20  Medium            Dining  11574.76
# 21  Medium         Education  14308.40
# 22  Medium       Electronics  15682.24
# ...
